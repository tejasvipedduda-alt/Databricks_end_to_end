# %%
datasets = [
    {
        "file_name": "orders"
    },
    {
        "file_name": "customer"
    },
    {
        "file_name": "products"
    }
]

# %%
#To use the dataset as input at runtime of jobs
dbutils.jobs.taskValues.set("output_dataset", datasets)
