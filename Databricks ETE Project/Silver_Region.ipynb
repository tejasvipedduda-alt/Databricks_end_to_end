# %%
df = spark.read.table("databricksete_cat.bronze.region")
display(df)

# %%
df = df.drop("_rescued_data")

# %%
df.write.format("delta").mode("overwrite").save("abfss://silver@tjdatabricksete.dfs.core.windows.net/regions")

# %%
#df = spark.read.load("abfss://silver@tjdatabricksete.dfs.core.windows.net/regions").display()

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricksete_cat.silver.regions_silver
USING DELTA
LOCATION 'abfss://silver@tjdatabricksete.dfs.core.windows.net/regions'
